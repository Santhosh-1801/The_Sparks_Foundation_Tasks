# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhosh-1801/The_Sparks_Foundation_Tasks/blob/main/DecisionTree_Task6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Santhosh Kumar**
#
# **Task 6**
#
# **Data Science & Business Analytics Intern at The Sparks Foundation**
#
# **Prediction using Decision Tree Algorithm**
#
# **Statement:Create the Decision Tree Classifier and visualize it graphically.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as py
import seaborn as sns

# %%
df1=pd.read_csv('/content/sample_data/Iris.csv')

# %%
df1
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df1.shape
# Out:
# (150, 6)

# %%
df1.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]>

# %%
df1.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df1.drop("Id", axis=1 , inplace=True)

# %%
df1.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
py.figure(figsize=(10,5))
sns.scatterplot(data=df1, s=100, alpha=0.7)
py.grid()
py.show()

# %%
#Extracting the data and classifying dependent and independent values
X=df1.iloc[:,:-1]
Y=df1.iloc[:,-1]

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
#training testing and splitting the available data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=25)

# %%
#Decision Tree Algorithm
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier( criterion="entropy" , max_depth = 5 )
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
y_prediction=classifier.predict(x_test)
y_prediction
# Out:
# array(['Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica'], dtype=object)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_prediction)
# Out:
# 0.9111111111111111

# %%
from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(y_test,y_prediction)
matrix
# Out:
# array([[17,  0,  0],
#        [ 0, 13,  3],
#        [ 0,  1, 11]])

# %%
from io import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree
from sklearn.tree import export_graphviz

# %%
text_rep=tree.export_text(classifier)
print(text_rep)
# Out:
# |--- feature_3 <= 0.80
# |   |--- class: Iris-setosa
# |--- feature_3 >  0.80
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 5.35
# |   |   |   |--- feature_3 <= 1.45
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_3 >  1.45
# |   |   |   |   |--- feature_1 <= 2.60
# |   |   |   |   |   |--- class: Iris-virginica
# |   |   |   |   |--- feature_1 >  2.60
# |   |   |   |   |   |--- class: Iris-versicolor
# |   |   |--- feature_2 >  5.35
# |   |   |   |--- class: Iris-virginica
# |   |--- feature_3 >  1.75
# |   |   |--- class: Iris-virginica

# %%
d_data=StringIO()
filename="iris_Classify.png"
features=df1.columns.tolist()[:-1]
target=df1['Species'].unique()
fig=py.figure(figsize=(15,15))
dt=tree.export_graphviz(classifier,feature_names=features,out_file=d_data,class_names=target,filled=True,rotate=False,rounded=True,special_characters=True)
graph=pydotplus.graph_from_dot_data(d_data.getvalue())
graph.write_png(filename)
img=mpimg.imread(filename)
py.figure(figsize=(100,200),dpi=100)
py.imshow(img,interpolation='nearest')
